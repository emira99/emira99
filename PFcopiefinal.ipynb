# %% [markdown]
# <a href="https://colab.research.google.com/github/emira99/emira99/blob/main/PFcopiefinal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import sys
import codecs
from math import sqrt
import numpy as np
import cv2
from PIL import Image
import imageio
import math
import matplotlib.pyplot as plt
from functools import reduce
import numpy

# %%
# !unrar x '/content/drive/MyDrive/GeorgeData/word_images_normalized.rar'
# Out:
# UNRAR 6.11 beta 1 freeware      Copyright (c) 1993-2022 Alexander Roshal
#
#
# Extracting from /content/drive/MyDrive/GeorgeData/word_images_normalized.rar
#
# Creating    word_images_normalized                                    OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# ...

# %%
path_image='/content/word_images_normalized/'

# %%
import codecs

def read_file(file_path):
    char_file = codecs.open(file_path, 'r', 'utf-8')
    liste = []
    for l in char_file:
        liste.append(l.strip())
    char_file.close()
    return liste

# List of file paths
file_paths = [
    '/content/drive/MyDrive/GeorgeData/test.txt',

]

for file_path in file_paths:
    l = read_file(file_path)
    print(l)
# Out:
# ['305-01', '305-02', '305-04', '305-05', '305-06', '305-07', '305-08', '305-09', '305-10', '305-11', '305-12', '305-13', '305-14', '305-15', '305-16', '305-17', '305-18', '305-19', '305-20', '305-21', '305-22', '305-23', '305-24', '305-25', '305-26', '305-27', '305-28', '305-30', '305-31', '305-32', '305-33', '305-34', '305-35', '305-36', '306-01', '306-03', '306-04', '306-05', '306-06', '306-07', '306-08', '306-09', '306-10', '306-11', '306-12', '306-13', '306-14', '306-15', '306-16', '306-17', '306-18', '306-19', '306-20', '306-21', '306-22', '306-24', '306-25', '306-26', '306-27', '306-28', '306-29', '306-30', '306-31', '306-32', '306-33', '306-34', '306-35', '307-02', '307-04', '307-05', '307-06', '307-07', '307-09', '307-10', '307-11', '307-12', '307-13', '307-14', '307-15', '307-16', '307-17', '307-18', '307-19', '307-20', '307-21', '307-22', '307-24', '307-25', '307-26', '307-27', '307-28', '307-29', '307-30', '307-31', '307-32', '307-33', '307-35', '307-36', '308-01', '308-03
# ...

# %%
import codecs

def read_file(file_path):
    char_file = codecs.open(file_path, 'r', 'utf-8')
    liste = []
    for l in char_file:
        liste.append(l.strip())
    char_file.close()
    return liste

# List of file paths
file_paths = [
    '/content/drive/MyDrive/GeorgeData/train.txt',

]

for file_path in file_paths:
    l = read_file(file_path)
    print(l)
# Out:
# ['270-01', '270-03', '270-04', '270-05', '270-06', '270-07', '270-08', '270-09', '270-10', '270-11', '270-12', '270-14', '270-15', '270-16', '270-17', '270-18', '270-19', '270-20', '270-21', '270-22', '270-23', '270-24', '270-25', '270-26', '270-27', '270-28', '270-29', '270-30', '270-31', '270-32', '270-33', '271-02', '271-04', '271-05', '271-06', '271-07', '271-08', '271-09', '271-10', '271-11', '271-12', '271-13', '271-14', '271-15', '271-16', '271-17', '271-18', '271-19', '271-21', '271-22', '271-23', '271-24', '271-25', '271-26', '271-27', '271-28', '271-29', '271-30', '271-31', '271-32', '271-33', '271-34', '271-35', '271-36', '272-02', '272-04', '272-05', '272-06', '272-07', '272-08', '272-09', '272-10', '272-11', '272-12', '272-13', '272-14', '272-15', '272-16', '272-17', '272-18', '272-19', '272-20', '272-21', '272-22', '272-23', '272-24', '272-25', '272-26', '272-27', '272-28', '272-29', '272-30', '272-31', '272-32', '272-33', '272-34', '272-35', '272-36', '273-01', '273-03
# ...

# %%
import codecs

def read_file(file_path):
    char_file = codecs.open(file_path, 'r', 'utf-8')
    liste = []
    for l in char_file:
        liste.append(l.strip())
    char_file.close()
    return liste

# List of file paths
file_paths = [
    '/content/drive/MyDrive/GeorgeData/valid.txt',

]

for file_path in file_paths:
    l = read_file(file_path)
    print(l)
# Out:
# ['300-02', '300-04', '300-05', '300-06', '300-07', '300-08', '300-09', '300-10', '300-11', '300-12', '300-14', '300-15', '300-16', '300-17', '300-18', '300-19', '300-20', '300-21', '300-22', '300-23', '300-24', '300-25', '300-26', '300-27', '300-28', '300-29', '300-30', '300-31', '300-32', '300-33', '300-34', '300-35', '301-03', '301-05', '301-06', '301-07', '301-08', '301-09', '301-10', '301-11', '301-12', '301-13', '301-14', '301-15', '301-16', '301-17', '301-18', '301-19', '301-20', '301-21', '301-22', '301-23', '301-24', '301-25', '301-26', '301-27', '301-28', '301-29', '301-30', '301-31', '301-32', '301-33', '301-34', '301-35', '301-36', '301-37', '302-01', '302-03', '302-04', '302-05', '302-06', '302-07', '302-08', '302-09', '302-10', '302-11', '302-12', '302-13', '302-14', '302-15', '302-16', '302-17', '302-18', '302-19', '302-20', '302-21', '302-22', '302-23', '302-24', '302-25', '302-26', '302-27', '302-28', '302-29', '302-30', '302-31', '302-32', '302-33', '302-34', '302-35
# ...

# %%
import os
l_train=[]
listim=os.listdir(path_image)#lister les images dans le chemin path_image


#train set
chemin_train='/content/drive/MyDrive/GeorgeData/train.txt' #définie déjà dans la partition
train=read_file(chemin_train) #la variable train contient la liste des lignes contenu dans le fichier train.txt
for t in train:
    ##search images in data/word_images_normalized/
      matched_lines = [s for s in listim if t in s]
      print(matched_lines)
      for l in matched_lines:
        l_train.append(l+'\n')
# Out:
# ['270-01-06.png', '270-01-05.png', '270-01-01.png', '270-01-04.png', '270-01-03.png', '270-01-07.png', '270-01-02.png']
# ['270-03-01.png', '270-03-04.png', '270-03-06.png', '270-03-07.png', '270-03-08.png', '270-03-05.png', '270-03-02.png', '270-03-03.png']
# ['270-04-04.png', '270-04-03.png', '270-04-02.png', '270-04-08.png', '270-04-01.png', '270-04-05.png', '270-04-07.png', '270-04-06.png']
# ['270-05-08.png', '270-05-07.png', '270-05-05.png', '270-05-02.png', '270-05-04.png', '270-05-06.png', '270-05-09.png', '270-05-03.png', '270-05-01.png']
# ['270-06-04.png', '270-06-05.png', '270-06-02.png', '270-06-06.png', '270-06-01.png', '270-06-03.png']
# ['270-07-03.png', '270-07-06.png', '270-07-02.png', '270-07-07.png', '270-07-05.png', '270-07-01.png', '270-07-04.png', '270-07-08.png']
# ['270-08-03.png', '270-08-01.png', '270-08-07.png', '270-08-06.png', '270-08-02.png', '270-08-04.png', '270-08-05.png']
# ...

# %%
def prepare_data():
    sets='/content/drive/MyDrive/GeorgeData/'
    l_train=[]
    l_valid=[]
    l_test=[]
    listim=os.listdir(path_image)


    #train set
    trf=sets+'train.txt' #définie déjà dans la partition
    train=read_file(trf) #la variable train contient la liste des lignes contenu dans le fichier train.txt
    for t in train:
        ##search images in data/word_images_normalized/
          matched_lines = [s for s in listim if t in s]
          for l in matched_lines:
            l_train.append(l+'\n')

    #test set
    trfs=sets+'test.txt'
    test=read_file(trfs)
    for t in test:
        ##search imges in data/word_images_normalized/
          matched_linesst = [s for s in listim if t in s]
          for l in matched_linesst:
              l_test.append(l+'\n')

    #valid set
    trfv=sets+'valid.txt'
    valid=read_file(trfv)
    for t in valid:
        ##search imges in data/word_images_normalized/
          matched_linesstv = [s for s in listim if t in s]
          for l in matched_linesstv:
            l_valid.append(l+'\n')

    f1=codecs.open('/content/drive/MyDrive/GeorgeData/train1.txt','w','utf8')
    f1.writelines(l_train)
    f2=codecs.open('/content/drive/MyDrive/GeorgeData/test1.txt','w','utf8')
    f2.writelines(l_test)
    f3=codecs.open('/content/drive/MyDrive/GeorgeData/valid1.txt','w','utf8')
    f3.writelines(l_valid)

# %%
prepare_data()

# %%
from skimage.feature import hog
import numpy as np
def hogs(path):
    img = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    dim=(50,50)
    resized = cv2.resize(img, dim, interpolation = cv2.INTER_AREA)
    gray = resized/255
    vector = hog(gray, orientations=12, block_norm='L1', pixels_per_cell=[5, 5], cells_per_block=[2, 2], feature_vector=True, visualize=False, transform_sqrt=True)

    return np.array(vector)

# %%
im='270-18-03.png'
vecteur=hogs(path_image+'/'+im)
print(len(vecteur))
#print(vecteur)
ct=''
for val in vecteur :
 ct= ct + ',' + str(val)
ct=ct[1:]
print(ct)
# Out:
# 3888
# ...

# %%
##################
import os
import numpy as np
from skimage.feature import hog
from skimage import io

def extract_hog_features(path_image):
    hog_features = []
    for image_path in path_image:
        try:
            # Load the image
            image = io.imread(path_image, as_gray=True)

            # Extract HOG features
            features = hog(image, pixels_per_cell=(8, 8), cells_per_block=(2, 2))

            hog_features.append(features)
        except Exception as e:
            print(f"Error processing {path_image}: {str(e)}")
            hog_features.append(None)

    return hog_features

# %%
def extractFeatsHOG():
    list_train=read_file('/content/drive/MyDrive/GeorgeData/train1.txt')
    Lt=[] ##une liste contenant les descripteur: line1: descripteur relatif à image 1 dans la liste train  etc....
    w=0
    for im in list_train:
        print(im)
        print(w)
        w+=1
        d=hogs(path_image+'/'+im)
        s=""
        i=0
        for v in d:
            if i==0 :
                s=str((v))
            else:
                s=s+ ',' + str((v))
            i+=1

        Lt.append(s.strip()+'\n')



    f3=codecs.open('/content/drive/MyDrive/GeorgeData/feats_train_hog.txt','w','utf8')
    f3.writelines(Lt)

    list_test=read_file('/content/drive/MyDrive/GeorgeData/test1.txt')
    Ls=[]
    for im in list_test:
        print(im)
        d=hogs(path_image+'/'+im)
        s=""
        i=0
        for v in d:
            if i==0 :
                s=str((v))
            else:
                s=s+ ',' + str((v))
            i+=1
        Ls.append(s.strip()+'\n')



    f=codecs.open('/content/drive/MyDrive/GeorgeData/feats_test_hog.txt','w','utf8')
    f.writelines(Ls)

    list_valid=read_file('/content/drive/MyDrive/GeorgeData/valid1.txt')
    Ls=[]
    for im in list_valid:
        print(im)
        d=hogs(path_image+'/'+im)
        s=""
        i=0
        for v in d:
            if i==0 :
                s=str((v))
            else:
                s=s+ ',' + str((v))
            i+=1
        Ls.append(s.strip()+'\n')



    f=codecs.open('/content/drive/MyDrive/GeorgeData/feats_valid_hog.txt','w','utf8')
    f.writelines(Ls)

# %%
#appel de la fonction pour l'extraction des caractéristiques dans des fichiers (3 fichiers)
extractFeatsHOG()
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# 1163
# 274-26-02.png
# 1164
# 274-26-04.png
# 1165
# 274-27-03.png
# 1166
# 274-27-06.png
# 1167
# 274-27-07.png
# 1168
# 274-27-01.png
# 1169
# 274-27-02.png
# 1170
# 274-27-04.png
# 1171
# 274-27-05.png
# 1172
# 274-28-05.png
# 1173
# 274-28-03.png
# 1174
# 274-28-04.png
# 1175
# 274-28-06.png
# 1176
# 274-28-01.png
# 1177
# 274-28-02.png
# 1178
# 274-29-02.png
# 1179
# 274-29-01.png
# 1180
# 274-29-06.png
# 1181
# 274-29-05.png
# 1182
# 274-29-07.png
# 1183
# 274-29-03.png
# 1184
# 274-29-04.png
# 1185
# 274-30-10.png
# 1186
# 274-30-07.png
# 1187
# 274-30-05.png
# 1188
# 274-30-06.png
# 1189
# 274-30-02.png
# 1190
# 274-30-01.png
# 1191
# 274-30-04.png
# 1192
# 274-30-09.png
# 1193
# 274-30-08.png
# 1194
# 274-30-03.png
# 1195
# 274-31-06.png
# 1196
# 274-31-01.png
# 1197
# 274-31-03.png
# 1198
# 274-31-08.png
# 1199
# 274-31-05.png
# 1200
# 274-31-07.png
# 1201
# 274-31-04.png
# 1202
# 274-31-02.png
# ...

# %%
def euclidean_distance(a, b):
    import numpy as np

    dist = np.sqrt(np.sum(np.square(a-b)))
    return dist

# %%
def compte_dist(v_train,v_test):
    import numpy as np
    list_im_Test= read_file('/content/drive/MyDrive/GeorgeData/test1.txt')
    i=0
    list_dict=dict()
    for im in list_im_Test:
        ##read feats test
        print(i)
        v_testx=v_test[i]
        j=0
        for im_test in list_im_Test:
            v_train1=v_train[j]
            #compute dict
            d=euclidean_distance(v_testx,v_train1)
            print(im,im_test,d)
            #print(im_train)
            #print(d)
            ###create dict
            list_dict[im_test]=d

            j+=1

        ###computing finished for each image in test set
        a = sorted(list_dict.items(), key=lambda x: x[1],reverse=False)
        i+=1
        fsave=im
        fsave=fsave.replace('png','txt')
        sab='/content/drive/MyDrive/GeorgeData/hog_euclidian/'

        with open(sab + fsave, 'w') as output_file:
            print(a, file=output_file)

# %%
def split_train_test():

    import numpy as np


    featsTrain=read_file('/content/drive/MyDrive/GeorgeData/feats_train_hog.txt')
    featsTest=read_file('/content/drive/MyDrive/GeorgeData/feats_test_hog.txt')
    list_im_Train=read_file('/content/drive/MyDrive/GeorgeData/train1.txt')
    list_im_Test= read_file('/content/drive/MyDrive/GeorgeData/test1.txt')

    X=[]
    j=0
    #parcourir la liste des images train
    for im_train in list_im_Train:
        #im_train contient le nom de l'image a la position j
        #v_train1 contient le vecteur carateristique relatif à l'image à la position j
        v_train1=featsTrain[j]
        #convertir le vecteur du texte en liste (separateur est le point virgule)
        v_trainspl=v_train1.split(',')
        ##j'affiche la longueur de mon vecteur de caractéristique
        #print('longueur feats  ',len(v_trainspl))
        ##convertir v_trainspl en array numpy
        v_trainx=np.asarray(v_trainspl)
        #forcer le type des valeur en float
        v_train=v_trainx.astype(np.float)
        #je remplis une nouvelle liste X avec les vecteur v_train
        X.append(v_train)
        j+=1
    #convertir la liste X en array
    X=np.array(X)###ensemble train


##le meme travail serait repeté avec l'ensemble de test
    i=0
    Y=[]
    for im in list_im_Test:
        print(im)
        ##read feats test

        v_test1=featsTest[i]
        v_testspl=v_test1.split(',')
        v_testx=np.asarray(v_testspl)
        v_test = v_testx.astype(np.float)
        Y.append(v_test)
        i+=1


    Y=np.array(Y)##ensemble de test (test set)
    return X,Y

# %%
import numpy as np
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

#charger les données dans X_train et X_test (features)
X_train,X_test=split_train_test()

print("X_train data shape: ", X_train.shape)
print("X_test data shape: ", X_test.shape)

#*****************normalisation des features************************
scaler = StandardScaler()
# Fit on training set only.
#concatener les feaures pour l'étape de normalisation
alldata=np.concatenate((X_train,X_test), axis=0)
## training
scaler.fit(alldata)

# Apply transform to both the training set and the test set.
X_train_normalised = scaler.transform(X_train)
X_test_normalised = scaler.transform(X_test)
##appliquer le PCA pour réduire la taille des données et selectionné les composantes pertinantes
#concatener les données
alldata_normalised=np.concatenate((X_train_normalised,X_test_normalised), axis=0)
#appeler l'algorithme PCA, nombre composants : 100
pca = PCA(n_components=100) #500
#entrainement du PCA
pca.fit(alldata_normalised)

#transformation des données: data reduction
X_test_selected = pca.transform(X_test_normalised)
# Out:
# <ipython-input-26-b11411fc29f2>:25: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   v_train=v_trainx.astype(np.float)
# 305-01-01.png
# 305-02-04.png
# 305-02-05.png
# 305-02-03.png
# 305-02-02.png
# 305-02-06.png
# 305-02-01.png
# 305-04-09.png
# 305-04-02.png
# 305-04-04.png
# 305-04-05.png
# 305-04-03.png
# 305-04-08.png
# 305-04-01.png
# 305-04-06.png
# 305-04-07.png
# 305-04-11.png
# 305-04-10.png
# 305-05-03.png
# 305-05-07.png
# 305-05-08.png
# 305-05-05.png
# 305-05-01.png
# 305-05-04.png
# 305-05-02.png
# 305-05-06.png
# 305-06-01.png
# 305-06-04.png
# 305-06-03.png
# 305-06-07.png
# 305-06-02.png
# 305-06-08.png
# 305-06-06.png
# 305-06-05.png
# ...

# %%
print(X_test.shape)
print(X_test_normalised.shape)
print(X_test_selected.shape)
# Out:
# (1168, 3888)
# (1168, 3888)
# (1168, 100)

# %%
##calcul des distances

np.save('/content/drive/MyDrive/GeorgeData/hog_euclidian/test_feat.npy', X_test_selected) # save

# %%
X_test_mydata=np.load('/content/drive/MyDrive/GeorgeData/hog_euclidian/test_feat.npy' )

# %%
print(X_test_mydata[1]) #afficher le vecteur à la position 2 (image 2, vecteur 2)
# Out:
# [ 5.55377481e+01  9.28626039e+00  3.37422125e+01 -2.82780311e+00
#   1.79882760e+01 -1.27653476e+01  3.60006633e+00  1.07101414e+01
#   1.50026934e+01 -2.86825975e-01 -2.05050037e-01  2.01598861e+01
#  -1.88136712e+01  5.14930166e+00 -2.95337825e+00  3.97246331e+00
#   3.11878763e+00  6.10861233e+00  5.52798658e+00 -1.32825744e+00
#  -7.47112244e+00  3.68899096e+00 -9.81008610e+00  9.69062200e+00
#  -1.06023535e+01  4.38077975e+00 -6.56780088e+00 -8.32394299e+00
#   6.74301982e+00  5.65537543e+00 -1.36192510e+00  4.16111625e+00
#  -3.92323486e+00 -4.39165468e+00 -1.36748245e+00  4.39782321e+00
#  -6.91072031e+00  1.25755008e+00  1.73492100e+00 -7.65128632e+00
#   1.33943922e+00  1.63200291e+00  3.97411281e+00 -3.57595796e+00
#  -1.91000574e+00  3.88198354e+00 -2.50409919e+00  8.86004490e-01
#   1.42706590e+00  1.76767358e+00  4.92398053e+00  5.57457589e+00
#   2.20058882e+00  3.79686713e+00  1.73986548e+00  3.14590126e-01
# ...

# %%
compte_dist(X_test_mydata,X_test_mydata)
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# 309-35-10.png 308-19-10.png 40.53450737255676
# 309-35-10.png 308-19-06.png 88.25255829232204
# 309-35-10.png 308-19-08.png 41.909402962273205
# 309-35-10.png 308-19-05.png 44.52165366898413
# 309-35-10.png 308-19-07.png 28.3279418217522
# 309-35-10.png 308-19-09.png 30.09630291707102
# 309-35-10.png 308-20-09.png 45.694046944498716
# 309-35-10.png 308-20-07.png 49.15112227606511
# 309-35-10.png 308-20-02.png 38.57151500246491
# 309-35-10.png 308-20-03.png 44.008867389558446
# 309-35-10.png 308-20-06.png 38.503895728066055
# 309-35-10.png 308-20-10.png 36.13561626763463
# 309-35-10.png 308-20-08.png 48.046718184035555
# 309-35-10.png 308-20-05.png 35.33148499523743
# 309-35-10.png 308-20-01.png 48.20435631597452
# 309-35-10.png 308-20-04.png 66.6921459174085
# 309-35-10.png 308-21-04.png 34.629653573225845
# 309-35-10.png 308-21-01.png 45.32971931221416
# 309-35-10.png 308-21-02.png 64.20851994891053
# ...

# %%
def normword(word):
    word=word.replace('s-s_cm','s')
    word=word.replace('s-s_mi','s')
    word=word.replace('s-s_pt','s')
    word=word.replace('s-s_sq','s')
    word=word.replace('s-s_qo','s')
    word=word.replace('s_cm','s')
    word=word.replace('s_mi','s')
    word=word.replace('s_pt','s')
    word=word.replace('s_sq','s')
    word=word.replace('s_qo','s')
    #word=word.lower()
    return word

# %%
def list_mot_test():
    lb='/content/drive/MyDrive/GeorgeData/word_labels.txt'
    l=read_file(lb)


    list_im_Test=read_file('/content/drive/MyDrive/GeorgeData/test1.txt')
    list_word_test=[]
    for im in list_im_Test:
        b=im.replace('.png','')
        ##je vais chercher le nom de l'images  dans la liste issue du fichier label
        matched_lines1= [s for s in l if b in s]
        word_train=matched_lines1[0].split(' ')[1].strip()
        word_train=normword(word_train)#le mot= le label= l'étiquette
        list_word_test.append(word_train)



    return list_word_test

# %%
l=list_mot_test()
print(l)
# Out:
# ['p-s-s_3-s_0-s_5', 'I-n-s-t-r-u-c-t-i-o-n-s', 'D-e-c-e-m-b-e-r', 'a-n-d', 'O-r-d-e-r-s', 's_1-s_7-s_5-s_5-s', 'L-e-t-t-e-r-s', 't-o', 'g-o', 'a', 'p-l-a-c-e', 't-o', 'a-m', 't-o', 'w-h-e-r-e', 'I', 'c-o-m-m-a-n-d-e-d', 'b-e', 'b-y', 'h-a-v-e', 'n-o', 'w-h-o', 'a-n-d', 'a-n-o-t-h-e-r-s', 'd-i-r-e-c-t-e-d', 'c-a-n', 'o-t-h-e-r', 't-h-a-t', 't-h-a-n', 'a', 'p-r-e-t-e-n-c-e-s', 'c-o-m-m-i-s_s', 'h-a-v-i-n-g', 'o-f', 's-i-o-n', 'f-r-o-m', 'K-i-n-g-s', 't-h-e', 'W-e', 'i-n', 'v-e-r-y', 's-u-f-f-e-r', 'g-r-e-a-t-l-y', 'a', 's-h-a-l-l', 'l-i-t-t-l-e', 'S-o-l-d-i-e-r-s', 'f-o-r', 'n-o-n-e', 't-i-m-e-s', 'a-n-d', 't-h-e', 'C-l-o-t-h-i-n-g', 'o-f', 'w-a-n-t', 'f-o-r', 'i-n', 'n-o-r', 'h-e-r-e-s', 'b-e', 'b-e-l-i-e-v-e', 'i-n', 's-h-o-r-t-s', 'h-a-d', 'I', 'c-a-n', 't-h-e', 'w-h-i-c-h', 'a-n-d', 'C-a-r-l-y-l-e', 'T-h-o-s-e', 'c-o-n-s', 'C-o-u-n-t-r-y-s', 'D-a-l-t-o-n', 'f-u-r-n-i-s-h-s', 'd-i-s-a-p-p-o-i-n-t-e-d', 'w-e', 'a-n-d', 'i-n-s', 't-o', 'a-r-e', 't-r-a-c-t-e-d', 'S-t-o-r-e-s', 'h-a-v-e
# ...

# %%
def cal_average(num):
    sum_num = 0
    for t in num:
        sum_num = sum_num + t

    avg = sum_num / len(num)
    return avg

# %%
import ast
def Precision(topk):
    list_word_test=list_mot_test()
    trouv=0
    listf=os.listdir('/content/drive/MyDrive/GeorgeData/hog_euclidian/')
    listf=sorted(listf)
    lb='/content/drive/MyDrive/GeorgeData/word_labels.txt'
    l=read_file(lb)
    cpt=0
    list_amp=[]
    nquery=0
    for f in listf:
        trouv=0
        result_dict='/content/drive/MyDrive/GeorgeData/hog_euclidian/' +f
        file = open(result_dict, "r")
        contents = file.read()
        d  = ast.literal_eval(contents)
        d=d[1:]###j'ai éliminé l'élément position 0 (cad la requete elle meme)
        im1=f.replace('.txt','')
        #print(im1)
        i=1
        ############loop over test set
        matched_lines = [s for s in l if im1 in s]
        word_truth=matched_lines[0].split(' ')[1].strip()
        query_truth=word_truth
        query_truth=normword(query_truth)
        ap=0
        nbest=0
        #parcourir la liste de resultats (dict--> list d)
        for item in d :
            if nbest==topk:###################results computed at top 10 best rank for all experiments
               break
            ##load du dictionnaire, key value
            k,v=item[0],item[1]
            im2=k.replace('.png','')
            matched_lines1= [s for s in l if im2 in s]
            word_pred=matched_lines1[0].split(' ')[1].strip()
            #print(query_truth,word_pred)
            word_pred=normword(word_pred)
            #comparaison du label requete et label retourné par le modèle keyword spotting
            if word_pred==query_truth:
                trouv+=1
                ap= trouv/i
            i+=1
            nbest+=1
        if ap==0:
            ave=0
        else:
            ave=ap

        print('average per query',im1,ave)
        list_amp.append(ave)
        nquery+=1
        if nquery==1168:
          break
    ##########average
    #import statistics

    precision_average=cal_average(list_amp)

    print('PRECISION TOP = %f %% , nb query %d ' %(precision_average*100,nquery))

# %%
Precision(1)
# Out:
# average per query 305-01-01 0
# average per query 305-02-01 1.0
# average per query 305-02-02 1.0
# average per query 305-02-03 1.0
# average per query 305-02-04 1.0
# average per query 305-02-05 1.0
# average per query 305-02-06 0
# average per query 305-04-01 1.0
# average per query 305-04-02 0
# average per query 305-04-03 1.0
# average per query 305-04-04 1.0
# average per query 305-04-05 0
# average per query 305-04-06 0
# average per query 305-04-07 1.0
# average per query 305-04-08 1.0
# average per query 305-04-09 1.0
# average per query 305-04-10 1.0
# average per query 305-04-11 0
# average per query 305-05-01 1.0
# average per query 305-05-02 0
# average per query 305-05-03 1.0
# average per query 305-05-04 0
# average per query 305-05-05 1.0
# average per query 305-05-06 1.0
# average per query 305-05-07 1.0
# average per query 305-05-08 0
# average per query 305-06-01 1.0
# average per query 305-06-02 0
# average per query 305-06-03 0
# average per query 305-06-04 0
# ...

# %%
import ast
def MAP():
    list_word_test=list_mot_test()
    trouv=0
    listf=os.listdir('/content/drive/MyDrive/GeorgeData/hog_euclidian/')
    listf=sorted(listf)
    lb='/content/drive/MyDrive/GeorgeData/word_labels.txt'
    l=read_file(lb)
    cpt=0
    list_amp=[]
    nquery=0
    for f in listf:
        trouv=0
        result_dict='/content/drive/MyDrive/GeorgeData/hog_euclidian/' +f
        file = open(result_dict, "r")
        contents = file.read()
        d  = ast.literal_eval(contents)
        d=d[1:]###j'ai éliminé l'élément position 0 (cad la requete elle meme)
        im1=f.replace('.txt','')
        #print(im1)
        i=1
        ############loop over test set
        matched_lines = [s for s in l if im1 in s]
        word_truth=matched_lines[0].split(' ')[1].strip()
        query_truth=word_truth
        query_truth=normword(query_truth)
        ap=0
        nbest=0
        #parcourir la liste de resultats (dict--> list d)
        for item in d :

            ##load du dictionnaire, key value
            k,v=item[0],item[1]
            im2=k.replace('.png','')
            matched_lines1= [s for s in l if im2 in s]
            word_pred=matched_lines1[0].split(' ')[1].strip()
            #print(query_truth,word_pred)
            word_pred=normword(word_pred)
            #comparaison du label requete et label retourné par le modèle keyword spotting
            if word_pred==query_truth:
                trouv+=1
                ap=ap+trouv/i
            i+=1
            nbest+=1
        if ap==0:
            ave=0
        else:
            ave=(1/trouv)*ap

        print('average per query',im1,ave)
        list_amp.append(ave)
        nquery+=1
        if nquery==1168:
          break
    ##########average
    #import statistics

    precision_average=cal_average(list_amp)

    print('Mean Average Precision MaP: ', precision_average*100)

# %%
MAP()
# Out:
# average per query 305-01-01 0
# average per query 305-02-01 0.7019927536231884
# average per query 305-02-02 0.8627450980392157
# average per query 305-02-03 0.4242587395672295
# average per query 305-02-04 0.7463235294117647
# average per query 305-02-05 0.6769341901577136
# average per query 305-02-06 0.02646425756792014
# average per query 305-04-01 0.6547705275249269
# average per query 305-04-02 0.25
# average per query 305-04-03 0.38723099828667173
# average per query 305-04-04 0.9462703962703962
# average per query 305-04-05 0
# average per query 305-04-06 0.010101010101010102
# average per query 305-04-07 0.4048469919606674
# average per query 305-04-08 1.0
# average per query 305-04-09 0.14231105159634405
# average per query 305-04-10 0.91917502787068
# average per query 305-04-11 0
# average per query 305-05-01 0.47824547660655653
# average per query 305-05-02 0
# average per query 305-05-03 0.19281022765197833
# average per query 305-05-04 0
# ...

# %% [markdown]
# ########################################################################
#
# * implémenter la partie avec les Resnet50-VGG16-Xception-MobileNet: pré-entrainés*

# %%
# !pip install keras.applications
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 kB 1.6 MB/s eta 0:00:00
# ...

# %%
#importation des bibliotèque nécessaire
import sys
import codecs
import os
from math import sqrt
import numpy as np
import cv2
from PIL import Image
import imageio
import math
import matplotlib.pyplot as plt
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.applications import Xception
from keras.applications.xception import preprocess_input
from keras.models import Model

# %%
def get_vector_xception(path):
    # load model
    model = Xception()
    # remove the output layer
    model = Model(inputs=model.inputs, outputs=model.layers[-2].output)
    # load an image from file
    image = load_img(path, target_size=(299, 299))

    # convert the image pixels to a numpy array
    image = img_to_array(image)

    # reshape data for the model
    image = image.reshape((1, image.shape[0], image.shape[1], image.shape[2]))

    # prepare the image for the resnet model
    image = preprocess_input(image)

    # get extracted features
    features = model.predict(image)
    features=np.array(features.flatten())

    # save to file
    return features

# %%
v1= get_vector_xception('/content/word_images_normalized/270-01-07.png')
c=''
for i in range(len(v1)):
  c=c+','+ str(v1[i])
print(c[1:])
print(len(v1))
# Out:
# ...
# 1/1 [==============================] - 2s 2s/step
# ...

# %%
def extractFeats_xception():
    list_train=read_file('/content/drive/MyDrive/GeorgeData/train1.txt')
    Lt=[] ##une liste contenant les descripteur: line1: descripteur relatif à image 1 dans la liste train  etc....
    w=0
    for im in list_train:
        print(im)
        print(w)
        w+=1
        d=get_vector_xception(path_image+'/'+im)
        s=""
        i=0
        for v in d:
            if i==0 :
                s=str((v))
            else:
                s=s+ ',' + str((v))
            i+=1

        Lt.append(s.strip()+'\n')



    f3=codecs.open('/content/drive/MyDrive/GeorgeData/feats_train_xception.txt','w','utf8')
    f3.writelines(Lt)

    list_test=read_file('/content/drive/MyDrive/GeorgeData/test1.txt')
    Ls=[]
    w=0
    for im in list_test:
        print(im)
        d=get_vector_xception(path_image+'/'+im)
        s=""
        i=0
        for v in d:
            if i==0 :
                s=str((v))
            else:
                s=s+ ',' + str((v))
            i+=1
        w+=1


        Ls.append(s.strip()+'\n')



    f=codecs.open('/content/drive/MyDrive/GeorgeData/feats_test_xception.txt','w','utf8')
    f.writelines(Ls)

    list_valid=read_file('/content/drive/MyDrive/GeorgeData/valid1.txt')
    Ls=[]
    w=0
    for im in list_valid:
        print(im)
        d=get_vector_xception(path_image+'/'+im)
        s=""
        i=0
        for v in d:
            if i==0 :
                s=str((v))
            else:
                s=s+ ',' + str((v))
            i+=1
        w+=1

        Ls.append(s.strip()+'\n')



    f=codecs.open('/content/drive/MyDrive/GeorgeData/feats_valid_xception.txt','w','utf8')
    f.writelines(Ls)

# %%
extractFeats_xception()
# Out:
# 270-01-06.png
# 0
# 1/1 [==============================] - 4s 4s/step
# 270-01-05.png
# 1
# 1/1 [==============================] - 4s 4s/step
# 270-01-01.png
# 2
# 1/1 [==============================] - 3s 3s/step
# 270-01-04.png
# 3
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7a7e1c72a320> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 4s 4s/step
# ...

# %%
def compte_dist_xception(v_train,v_test):
    import numpy as np
    list_im_Test= read_file('/content/drive/MyDrive/GeorgeData/test1.txt')
    i=0
    list_dict=dict()
    for im in list_im_Test:
        ##read feats test
        print(i)

        v_testx=v_test[i]
        j=0
        for im_test in list_im_Test:
            v_train1=v_train[j]
            #compute dict
            d=euclidean_distance(v_testx,v_train1)
            print(im,im_test,d)
            #print(im_train)
            #print(d)
            ###create dict
            list_dict[im_test]=d

            j+=1

        ###computing finished for each image in test set
        a = sorted(list_dict.items(), key=lambda x: x[1],reverse=False)
        i+=1
        fsave=im
        fsave=fsave.replace('png','txt')
        sab='/content/drive/MyDrive/GeorgeData/xception_euclidian/'

        with open(sab + fsave, 'w') as output_file:
            print(a, file=output_file)

# %%
def split_train_test_xception():

    import numpy as np


    featsTrain=read_file('/content/drive/MyDrive/GeorgeData/feats_train_xception.txt')
    featsTest=read_file('/content/drive/MyDrive/GeorgeData/feats_test_xception.txt')
    list_im_Train=read_file('/content/drive/MyDrive/GeorgeData/train1.txt')
    list_im_Test= read_file('/content/drive/MyDrive/GeorgeData/test1.txt')

    X=[]
    j=0
    #parcourir la liste des images train
    for im_train in list_im_Train:
        #im_train contient le nom de l'image a la position j
        #v_train1 contient le vecteur carateristique relatif à l'image à la position j
        v_train1=featsTrain[j]
        #convertir le vecteur du texte en liste (separateur est le point virgule)
        v_trainspl=v_train1.split(',')
        ##j'affiche la longueur de mon vecteur de caractéristique
        #print('longueur feats  ',len(v_trainspl))
        ##convertir v_trainspl en array numpy
        v_trainx=np.asarray(v_trainspl)
        #forcer le type des valeur en float
        v_train=v_trainx.astype(np.float)
        #je remplis une nouvelle liste X avec les vecteur v_train
        X.append(v_train)
        j+=1

    #convertir la liste X en array
    X=np.array(X)###ensemble train


##le meme travail serait repeté avec l'ensemble de test
    i=0
    Y=[]
    for im in list_im_Test:
        print(im)
        ##read feats test

        v_test1=featsTest[i]
        v_testspl=v_test1.split(',')
        v_testx=np.asarray(v_testspl)
        v_test = v_testx.astype(np.float)
        Y.append(v_test)
        i+=1



    Y=np.array(Y)##ensemble de test (test set)
    return X,Y

# %%
import numpy as np
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

#charger les données dans X_train et X_test (features)
X_train,X_test=split_train_test_xception()

print("X_train data shape: ", X_train.shape)
print("X_test data shape: ", X_test.shape)

#*****************normalisation des features************************
scaler = StandardScaler()
# Fit on training set only.
#concatener les feaures pour l'étape de normalisation
alldata=np.concatenate((X_train,X_test), axis=0)
## training
scaler.fit(alldata)

# Apply transform to both the training set and the test set.
X_train_normalised = scaler.transform(X_train)
X_test_normalised = scaler.transform(X_test)
##appliquer le PCA pour réduire la taille des données et selectionné les composantes pertinantes
#concatener les données
alldata_normalised=np.concatenate((X_train_normalised,X_test_normalised), axis=0)
#appeler l'algorithme PCA, nombre composants : 100
pca = PCA(n_components=130)
#entrainement du PCA
pca.fit(alldata_normalised)

#transformation des données: data reduction
X_test_selected = pca.transform(X_test_normalised)
# Out:
# <ipython-input-2-70636bcd80af>:25: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   v_train=v_trainx.astype(np.float)
# 305-01-01.png
# 305-02-04.png
# 305-02-05.png
# 305-02-03.png
# 305-02-02.png
# 305-02-06.png
# 305-02-01.png
# 305-04-09.png
# 305-04-02.png
# 305-04-04.png
# 305-04-05.png
# 305-04-03.png
# 305-04-08.png
# 305-04-01.png
# 305-04-06.png
# 305-04-07.png
# 305-04-11.png
# 305-04-10.png
# 305-05-03.png
# 305-05-07.png
# 305-05-08.png
# 305-05-05.png
# 305-05-01.png
# 305-05-04.png
# 305-05-02.png
# 305-05-06.png
# 305-06-01.png
# 305-06-04.png
# 305-06-03.png
# 305-06-07.png
# 305-06-02.png
# 305-06-08.png
# 305-06-06.png
# 305-06-05.png
# ...

# %%
print(X_test.shape)
print(X_test_normalised.shape)
print(X_test_selected.shape)
##calcul des distances
# Out:
# (1168, 2048)
# (1168, 2048)
# (1168, 130)

# %%
np.save('/content/drive/MyDrive/GeorgeData/xception_euclidian/test_feat.npy', X_test_selected) # save
X_test_mydata=np.load('/content/drive/MyDrive/GeorgeData/xception_euclidian/test_feat.npy' )

# %%
##calculer les distances
compte_dist_xception(X_test_mydata,X_test_mydata)
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# 309-35-10.png 308-19-10.png 40.53450737255676
# 309-35-10.png 308-19-06.png 88.25255829232204
# 309-35-10.png 308-19-08.png 41.909402962273205
# 309-35-10.png 308-19-05.png 44.52165366898413
# 309-35-10.png 308-19-07.png 28.3279418217522
# 309-35-10.png 308-19-09.png 30.09630291707102
# 309-35-10.png 308-20-09.png 45.694046944498716
# 309-35-10.png 308-20-07.png 49.15112227606511
# 309-35-10.png 308-20-02.png 38.57151500246491
# 309-35-10.png 308-20-03.png 44.008867389558446
# 309-35-10.png 308-20-06.png 38.503895728066055
# 309-35-10.png 308-20-10.png 36.13561626763463
# 309-35-10.png 308-20-08.png 48.046718184035555
# 309-35-10.png 308-20-05.png 35.33148499523743
# 309-35-10.png 308-20-01.png 48.20435631597452
# 309-35-10.png 308-20-04.png 66.6921459174085
# 309-35-10.png 308-21-04.png 34.629653573225845
# 309-35-10.png 308-21-01.png 45.32971931221416
# 309-35-10.png 308-21-02.png 64.20851994891053
# ...

# %%
import ast
def Precision_xception(topk):
    list_word_test=list_mot_test()
    trouv=0
    listf=os.listdir('/content/drive/MyDrive/GeorgeData/xception_euclidian/')
    listf=sorted(listf)
    lb='/content/drive/MyDrive/GeorgeData/word_labels.txt'
    l=read_file(lb)
    cpt=0
    list_amp=[]
    nquery=0
    for f in listf:
        trouv=0
        result_dict='/content/drive/MyDrive/GeorgeData/xception_euclidian/' +f
        file = open(result_dict, "r")
        contents = file.read()
        d  = ast.literal_eval(contents)
        d=d[1:]###j'ai éliminé l'élément position 0 (cad la requete elle meme)
        im1=f.replace('.txt','')
        #print(im1)
        i=1
        ############loop over test set
        matched_lines = [s for s in l if im1 in s]
        word_truth=matched_lines[0].split(' ')[1].strip()
        query_truth=word_truth
        query_truth=normword(query_truth)
        ap=0
        nbest=0
        #parcourir la liste de resultats (dict--> list d)
        for item in d :
            if nbest==topk:###################results computed at top 10 best rank for all experiments
               break
            ##load du dictionnaire, key value
            k,v=item[0],item[1]
            im2=k.replace('.png','')
            matched_lines1= [s for s in l if im2 in s]
            word_pred=matched_lines1[0].split(' ')[1].strip()
            #print(query_truth,word_pred)
            word_pred=normword(word_pred)
            #comparaison du label requete et label retourné par le modèle keyword spotting
            if word_pred==query_truth:
                trouv+=1
                ap= trouv/i
            i+=1
            nbest+=1
        if ap==0:
            ave=0
        else:
            ave=ap

        print('average per query',im1,ave)
        list_amp.append(ave)
        nquery+=1
        if nquery==1168:
          break

    ##########average
    #import statistics

    precision_average=cal_average(list_amp)

    print('PRECISION TOP = %f %% , nb query %d ' %(precision_average*100,nquery))

# %%
Precision_xception(100) ##1
# Out:
# average per query 305-01-01 0
# average per query 305-02-01 0.06976744186046512
# average per query 305-02-02 0.05952380952380952
# average per query 305-02-03 0.22916666666666666
# average per query 305-02-04 0.1
# average per query 305-02-05 0.1746031746031746
# average per query 305-02-06 0.2857142857142857
# average per query 305-04-01 0.18
# average per query 305-04-02 0.01694915254237288
# average per query 305-04-03 0.2222222222222222
# average per query 305-04-04 0.08928571428571429
# average per query 305-04-05 0
# average per query 305-04-06 0
# average per query 305-04-07 0.057971014492753624
# average per query 305-04-08 0.03225806451612903
# average per query 305-04-09 0.21505376344086022
# average per query 305-04-10 0.15217391304347827
# average per query 305-04-11 0
# average per query 305-05-01 0.17204301075268819
# average per query 305-05-02 0
# average per query 305-05-03 0.05405405405405406
# average per query 305-05-04 0
# ...

# %%
import ast
def MAP_xception():
    list_word_test=list_mot_test()
    trouv=0
    listf=os.listdir('/content/drive/MyDrive/GeorgeData/xception_euclidian/')
    listf=sorted(listf)
    lb='/content/drive/MyDrive/GeorgeData/word_labels.txt'
    l=read_file(lb)
    cpt=0
    list_amp=[]
    nquery=0
    for f in listf:
        trouv=0
        result_dict='/content/drive/MyDrive/GeorgeData/xception_euclidian/' +f
        file = open(result_dict, "r")
        contents = file.read()
        d  = ast.literal_eval(contents)
        d=d[1:]###j'ai éliminé l'élément position 0 (cad la requete elle meme)
        im1=f.replace('.txt','')
        #print(im1)
        i=1
        ############loop over test set
        matched_lines = [s for s in l if im1 in s]
        word_truth=matched_lines[0].split(' ')[1].strip()
        query_truth=word_truth
        query_truth=normword(query_truth)
        ap=0
        nbest=0
        #parcourir la liste de resultats (dict--> list d)
        for item in d :

            ##load du dictionnaire, key value
            k,v=item[0],item[1]
            im2=k.replace('.png','')
            matched_lines1= [s for s in l if im2 in s]
            word_pred=matched_lines1[0].split(' ')[1].strip()
            #print(query_truth,word_pred)
            word_pred=normword(word_pred)
            #comparaison du label requete et label retourné par le modèle keyword spotting
            if word_pred==query_truth:
                trouv+=1
                ap=ap+trouv/i
            i+=1
            nbest+=1
        if ap==0:
            ave=0
        else:
            ave=(1/trouv)*ap

        print('average per query',im1,ave)
        list_amp.append(ave)
        nquery+=1
        if nquery==1168:
          break
    ##########average
    #import statistics

    precision_average=cal_average(list_amp)

    print('Mean Average Precision MaP : ',precision_average*100)

# %%
MAP_xception()
# Out:
# average per query 305-01-01 0
# average per query 305-02-01 0.09203829207089367
# average per query 305-02-02 0.3910440613026819
# average per query 305-02-03 0.36446979561446247
# average per query 305-02-04 0.24242424242424243
# average per query 305-02-05 0.48318679689466926
# average per query 305-02-06 0.6935503266075957
# average per query 305-04-01 0.2103823108852515
# average per query 305-04-02 0.01694915254237288
# average per query 305-04-03 0.20344204237606728
# average per query 305-04-04 0.17855500552864015
# average per query 305-04-05 0
# average per query 305-04-06 0.0011614401858304297
# average per query 305-04-07 0.04863022661036104
# average per query 305-04-08 0.03225806451612903
# average per query 305-04-09 0.1749877780902648
# average per query 305-04-10 0.3231850673790269
# average per query 305-04-11 0
# average per query 305-05-01 0.34491296790886283
# average per query 305-05-02 0
# average per query 305-05-03 0.04221690121935564
# ...

# %%
# !pip install keras.applications
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 kB 1.5 MB/s eta 0:00:00
# ...

# %%
#importation des bibliotèque nécessaire
import sys
import codecs
import os
from math import sqrt
import numpy as np
import cv2
from PIL import Image
import imageio
import math
import matplotlib.pyplot as plt
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.models import Model

# %%
def loadmodel():
    from transformers import ViTFeatureExtractor, ViTModel

    feature_extractor = ViTFeatureExtractor.from_pretrained('google/vit-base-patch16-224-in21k')
    model = ViTModel.from_pretrained('google/vit-base-patch16-224-in21k')
    return model,feature_extractor

# %%
def get_vector_transformer(path):
    # load model
    model,feature_extractor=loadmodel()
    #print('le modèle: ', model)
    #print('le feature extracytor: ', feature_extractor)
    original_image = Image.open(path)
    newsize = (100, 100)
    original_image = original_image.resize(newsize)
    #print('image originale: ', original_image)
    rgb_image = original_image.convert('RGB')
    #print('image RGB: ', rgb_image)

    inputs = feature_extractor(images=rgb_image, return_tensors="pt")
    #print('inputs: ', inputs)
    outputs = model(**inputs)
    #print('outputs: ', outputs)
    last_hidden_states = outputs.last_hidden_state
    last_hidden_states=last_hidden_states.flatten()
    #print('last_hidden_states : ' ,last_hidden_states)
    feats=last_hidden_states.detach().numpy()
    #print('feats: ',feats)
    #print('feats.flatten(): ', feats.flatten())
    features=np.array(feats)
    #print('features : ', features)

    # save to file
    return features

# %%
v1=get_vector_transformer('/content/word_images_normalized/270-01-07.png')
# Out:
# preprocessor_config.json:   0%|          | 0.00/160 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/models/vit/feature_extraction_vit.py:28: FutureWarning: The class ViTFeatureExtractor is deprecated and will be removed in version 5 of Transformers. Please use ViTImageProcessor instead.
#   warnings.warn(
# config.json:   0%|          | 0.00/502 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/346M [00:00<?, ?B/s]

# %%
def extractFeats_transformer():
    list_train=read_file('/content/drive/MyDrive/GeorgeData/train1.txt')
    Lt=[] ##une liste contenant les descripteur: line1: descripteur relatif à image 1 dans la liste train  etc....
    w=0
    for im in list_train:
        print(im)
        print(w)
        w+=1
        d=get_vector_transformer(path_image+'/'+im)
        s=""
        i=0
        for v in d:
            if i==0 :
                s=str((v))
            else:
                s=s+ ',' + str((v))
            i+=1
        if w==20:
          break
        Lt.append(s.strip()+'\n')



    f3=codecs.open('/content/drive/MyDrive/GeorgeData/feats_train_transformer.txt','w','utf8')
    f3.writelines(Lt)

    list_test=read_file('/content/drive/MyDrive/GeorgeData/test1.txt')
    Ls=[]
    w=0
    for im in list_test:
        print(im)
        d=get_vector_transformer(path_image+'/'+im)
        s=""
        i=0
        for v in d:
            if i==0 :
                s=str((v))
            else:
                s=s+ ',' + str((v))
            i+=1
        w+=1

        if w==100:
          break
        Ls.append(s.strip()+'\n')



    f=codecs.open('/content/drive/MyDrive/GeorgeData/feats_test_transformer.txt','w','utf8')
    f.writelines(Ls)

    list_valid=read_file('/content/drive/MyDrive/GeorgeData/valid1.txt')
    Ls=[]
    w=0
    for im in list_valid:
        print(im)
        d=get_vector_transformer(path_image+'/'+im)
        s=""
        i=0
        for v in d:
            if i==0 :
                s=str((v))
            else:
                s=s+ ',' + str((v))
            i+=1
        w+=1
        if w==5:
          break
        Ls.append(s.strip()+'\n')



    f=codecs.open('/content/drive/MyDrive/GeorgeData/feats_valid_transformer.txt','w','utf8')
    f.writelines(Ls)

# %%
extractFeats_transformer()
# Out:
# 270-01-06.png
# 0
# 270-01-05.png
# 1
# 270-01-01.png
# 2
# 270-01-04.png
# 3
# 270-01-03.png
# 4
# 270-01-07.png
# 5
# 270-01-02.png
# 6
# 270-03-01.png
# 7
# 270-03-04.png
# 8
# 270-03-06.png
# 9
# 270-03-07.png
# 10
# 270-03-08.png
# 11
# 270-03-05.png
# 12
# 270-03-02.png
# 13
# 270-03-03.png
# 14
# 270-04-04.png
# 15
# 270-04-03.png
# 16
# 270-04-02.png
# 17
# 270-04-08.png
# 18
# 270-04-01.png
# 19
# 305-01-01.png
# 305-02-04.png
# 305-02-05.png
# 305-02-03.png
# 305-02-02.png
# 305-02-06.png
# 305-02-01.png
# 305-04-09.png
# 305-04-02.png
# 305-04-04.png
# 305-04-05.png
# 305-04-03.png
# 305-04-08.png
# 305-04-01.png
# 305-04-06.png
# 305-04-07.png
# 305-04-11.png
# 305-04-10.png
# 305-05-03.png
# 305-05-07.png
# 305-05-08.png
# 305-05-05.png
# 305-05-01.png
# 305-05-04.png
# 305-05-02.png
# 305-05-06.png
# 305-06-01.png
# 305-06-04.png
# 305-06-03.png
# 305-06-07.png
# 305-06-02.png
# 305-06-08.png
# 305-06-06.png
# 305-06-05.png
# 305-07-01.png
# 305-07-02.png
# ...

# %%
def compte_dist_transformer(v_train,v_test):
    import numpy as np
    list_im_Test= read_file('/content/drive/MyDrive/GeorgeData/test1.txt')
    i=0
    list_dict=dict()
    for im in list_im_Test:
        ##read feats test
        print(i)

        v_testx=v_test[i]
        j=0
        for im_test in list_im_Test:
            v_train1=v_train[j]
            #compute dict
            d=euclidean_distance(v_testx,v_train1)
            print(im,im_test,d)
            #print(im_train)
            #print(d)
            ###create dict
            list_dict[im_test]=d

            j+=1

        ###computing finished for each image in test set
        a = sorted(list_dict.items(), key=lambda x: x[1],reverse=False)
        i+=1
        fsave=im
        fsave=fsave.replace('png','txt')
        sab='/content/drive/MyDrive/GeorgeData/transformer_euclidian/'

        with open(sab + fsave, 'w') as output_file:
            print(a, file=output_file)

# %%
def split_train_test_transformer():

    import numpy as np


    featsTrain=read_file('/content/drive/MyDrive/GeorgeData/feats_train_transformer.txt')
    featsTest=read_file('/content/drive/MyDrive/GeorgeData/feats_test_transformer.txt')
    list_im_Train=read_file('/content/drive/MyDrive/GeorgeData/train1.txt')
    list_im_Test= read_file('/content/drive/MyDrive/GeorgeData/test1.txt')

    X=[]
    j=0
    #parcourir la liste des images train
    for im_train in list_im_Train:
        #im_train contient le nom de l'image a la position j
        #v_train1 contient le vecteur carateristique relatif à l'image à la position j
        v_train1=featsTrain[j]
        #convertir le vecteur du texte en liste (separateur est le point virgule)
        v_trainspl=v_train1.split(',')
        ##j'affiche la longueur de mon vecteur de caractéristique
        #print('longueur feats  ',len(v_trainspl))
        ##convertir v_trainspl en array numpy
        v_trainx=np.asarray(v_trainspl)
        #forcer le type des valeur en float
        v_train=v_trainx.astype(np.float)
        #je remplis une nouvelle liste X avec les vecteur v_train
        X.append(v_train)
        j+=1

    #convertir la liste X en array
    X=np.array(X)###ensemble train


##le meme travail serait repeté avec l'ensemble de test
    i=0
    Y=[]
    for im in list_im_Test:
        print(im)
        ##read feats test

        v_test1=featsTest[i]
        v_testspl=v_test1.split(',')
        v_testx=np.asarray(v_testspl)
        v_test = v_testx.astype(np.float)
        Y.append(v_test)
        i+=1



    Y=np.array(Y)##ensemble de test (test set)
    return X,Y

# %%
import numpy as np
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# Supposons que la fonction split_train_test_transformer() ressemble à ceci :
def split_train_test_transformer():
    # ... (votre code pour charger les données)
    featsTrain = [...]  # Vos données d'entraînement
    featsTest = [...]   # Vos données de test

    # Vérifiez que featsTrain n'est pas vide
    if not featsTrain:
        print("Erreur: featsTrain est vide.")
        return None, None

    # Reste du code pour préparer X_train et X_test
    # ...

    return X_train, X_test

# Charger les données dans X_train et X_test (features)
X_train, X_test = split_train_test_transformer()

# Vérifier si X_train et X_test sont définis avant de continuer
if X_train is not None and X_test is not None:
    print("X_train data shape: ", X_train.shape)
    print("X_test data shape: ", X_test.shape)

    # ***************** Normalisation des features ************************
    scaler = StandardScaler()

    # Concaténer les features pour l'étape de normalisation
    alldata = np.concatenate((X_train, X_test), axis=0)

    # Entraîner le scaler sur l'ensemble de données combiné
    scaler.fit(alldata)

    # Appliquer la transformation sur l'ensemble d'entraînement et de test
    X_train_normalised = scaler.transform(X_train)
    X_test_normalised = scaler.transform(X_test)

    # Appliquer le PCA pour réduire la taille des données et sélectionner les composantes pertinentes

    # Concaténer les données normalisées
    alldata_normalised = np.concatenate((X_train_normalised, X_test_normalised), axis=0)

    # Appeler l'algorithme PCA, nombre de composants : 130
    pca = PCA(n_components=130)

    # Entraînement du PCA
    pca.fit(alldata_normalised)

    # Transformation des données : réduction de la dimension
    X_test_selected = pca.transform(X_test_normalised)
else:
    print("Erreur lors du chargement des données.")
# Out:
# X_train data shape:  (2433, 2048)
# X_test data shape:  (1168, 2048)

# %%
print(X_test.shape)
print(X_test_normalised.shape)
print(X_test_selected.shape)
##calcul des distances
# Out:
# (1168, 2048)
# (1168, 2048)
# (1168, 130)

# %%
np.save('/content/drive/MyDrive/GeorgeData/transformer_euclidian/test_feat.npy', X_test_selected) # save
X_test_mydata=np.load('/content/drive/MyDrive/GeorgeData/transformer_euclidian/test_feat.npy' )

# %%
##calculer les distances
compte_dist_transformer(X_test_mydata,X_test_mydata)
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# 309-35-10.png 308-19-10.png 40.53097685455162
# 309-35-10.png 308-19-06.png 88.32598092845681
# 309-35-10.png 308-19-08.png 41.86239212610498
# 309-35-10.png 308-19-05.png 44.61041724136303
# 309-35-10.png 308-19-07.png 28.472610977381173
# 309-35-10.png 308-19-09.png 30.09815746268264
# 309-35-10.png 308-20-09.png 45.6866408920454
# 309-35-10.png 308-20-07.png 49.101247104383006
# 309-35-10.png 308-20-02.png 38.51058614589803
# 309-35-10.png 308-20-03.png 43.28032270756412
# 309-35-10.png 308-20-06.png 38.676563171062966
# 309-35-10.png 308-20-10.png 36.15258006777465
# 309-35-10.png 308-20-08.png 48.1225428063313
# 309-35-10.png 308-20-05.png 35.354075023605596
# 309-35-10.png 308-20-01.png 48.22855808585666
# 309-35-10.png 308-20-04.png 66.65567036157965
# 309-35-10.png 308-21-04.png 34.63082857994139
# 309-35-10.png 308-21-01.png 45.332487753449
# 309-35-10.png 308-21-02.png 64.14681766487568
# ...

# %%
import ast
def Precision_transformer(topk):
    list_word_test=list_mot_test()
    trouv=0
    listf=os.listdir('/content/drive/MyDrive/GeorgeData/transformer_euclidian/')
    listf=sorted(listf)
    lb='/content/drive/MyDrive/GeorgeData/word_labels.txt'
    l=read_file(lb)
    cpt=0
    list_amp=[]
    nquery=0
    for f in listf:
        trouv=0
        result_dict='/content/drive/MyDrive/GeorgeData/transformer_euclidian/' +f
        file = open(result_dict, "r")
        contents = file.read()
        d  = ast.literal_eval(contents)
        d=d[1:]###j'ai éliminé l'élément position 0 (cad la requete elle meme)
        im1=f.replace('.txt','')
        #print(im1)
        i=1
        ############loop over test set
        matched_lines = [s for s in l if im1 in s]
        word_truth=matched_lines[0].split(' ')[1].strip()
        query_truth=word_truth
        query_truth=normword(query_truth)
        ap=0
        nbest=0
        #parcourir la liste de resultats (dict--> list d)
        for item in d :
            if nbest==topk:###################results computed at top 10 best rank for all experiments
               break
            ##load du dictionnaire, key value
            k,v=item[0],item[1]
            im2=k.replace('.png','')
            matched_lines1= [s for s in l if im2 in s]
            word_pred=matched_lines1[0].split(' ')[1].strip()
            #print(query_truth,word_pred)
            word_pred=normword(word_pred)
            #comparaison du label requete et label retourné par le modèle keyword spotting
            if word_pred==query_truth:
                trouv+=1
                ap= trouv/i
            i+=1
            nbest+=1
        if ap==0:
            ave=0
        else:
            ave=ap

        print('average per query',im1,ave)
        list_amp.append(ave)
        nquery+=1
        if nquery==1168:
          break

    ##########average
    #import statistics

    precision_average=cal_average(list_amp)

    print('PRECISION TOP = %f %% , nb query %d ' %(precision_average*100,nquery))

# %%
Precision_transformer(100)
# Out:
# average per query 305-01-01 0
# average per query 305-02-01 0.07317073170731707
# average per query 305-02-02 0.056818181818181816
# average per query 305-02-03 0.22448979591836735
# average per query 305-02-04 0.10256410256410256
# average per query 305-02-05 0.16923076923076924
# average per query 305-02-06 0.2926829268292683
# average per query 305-04-01 0.24285714285714285
# average per query 305-04-02 0.01818181818181818
# average per query 305-04-03 0.21
# average per query 305-04-04 0.08333333333333333
# average per query 305-04-05 0
# average per query 305-04-06 0
# average per query 305-04-07 0.05970149253731343
# average per query 305-04-08 0.03333333333333333
# average per query 305-04-09 0.20652173913043478
# average per query 305-04-10 0.15384615384615385
# average per query 305-04-11 0
# average per query 305-05-01 0.17391304347826086
# average per query 305-05-02 0
# average per query 305-05-03 0.05194805194805195
# average per query 305-05-04 0
# ...

# %%
import ast
def MAP_transformer():
    list_word_test=list_mot_test()
    trouv=0
    listf=os.listdir('/content/drive/MyDrive/GeorgeData/transformer_euclidian/')
    listf=sorted(listf)
    lb='/content/drive/MyDrive/GeorgeData/word_labels.txt'
    l=read_file(lb)
    cpt=0
    list_amp=[]
    nquery=0
    for f in listf:
        trouv=0
        result_dict='/content/drive/MyDrive/GeorgeData/transformer_euclidian/' +f
        file = open(result_dict, "r")
        contents = file.read()
        d  = ast.literal_eval(contents)
        d=d[1:]###j'ai éliminé l'élément position 0 (cad la requete elle meme)
        im1=f.replace('.txt','')
        #print(im1)
        i=1
        ############loop over test set
        matched_lines = [s for s in l if im1 in s]
        word_truth=matched_lines[0].split(' ')[1].strip()
        query_truth=word_truth
        query_truth=normword(query_truth)
        ap=0
        nbest=0
        #parcourir la liste de resultats (dict--> list d)
        for item in d :

            ##load du dictionnaire, key value
            k,v=item[0],item[1]
            im2=k.replace('.png','')
            matched_lines1= [s for s in l if im2 in s]
            word_pred=matched_lines1[0].split(' ')[1].strip()
            #print(query_truth,word_pred)
            word_pred=normword(word_pred)
            #comparaison du label requete et label retourné par le modèle keyword spotting
            if word_pred==query_truth:
                trouv+=1
                ap=ap+trouv/i
            i+=1
            nbest+=1
        if ap==0:
            ave=0
        else:
            ave=(1/trouv)*ap

        print('average per query',im1,ave)
        list_amp.append(ave)
        nquery+=1
        if nquery==1168:
          break
    ##########average
    #import statistics

    precision_average=cal_average(list_amp)

    print('Mean Average Precision MaP : ',precision_average*100)

# %%
MAP_transformer()
# Out:
# average per query 305-01-01 0
# average per query 305-02-01 0.0919079859694918
# average per query 305-02-02 0.3888714063714063
# average per query 305-02-03 0.3666517551928214
# average per query 305-02-04 0.246474358974359
# average per query 305-02-05 0.4832105270620553
# average per query 305-02-06 0.701393504941108
# average per query 305-04-01 0.20882367160089924
# average per query 305-04-02 0.01818181818181818
# average per query 305-04-03 0.20539846134746456
# average per query 305-04-04 0.18430457106263853
# average per query 305-04-05 0
# average per query 305-04-06 0.0011668611435239206
# average per query 305-04-07 0.0521304084594372
# average per query 305-04-08 0.03333333333333333
# average per query 305-04-09 0.17609873776121696
# average per query 305-04-10 0.3175150992127997
# average per query 305-04-11 0
# average per query 305-05-01 0.34541190570409314
# average per query 305-05-02 0
# average per query 305-05-03 0.042214022569456465
# ...
